# %% [markdown]
# # Bluefin Testing Notebook
#
# This is a notebook for exploring some testing concepts

# %%
#a passing test
test_result = 2 + 2

assert test_result == 4

# %%
#a failing test
test_result = 2 + 2

assert test_result == 5
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-ff0e28cce8d8> in <module>()
#       2 test_result = 2 + 2
#       3
# ----> 4 assert test_result == 5
#
# AssertionError:
